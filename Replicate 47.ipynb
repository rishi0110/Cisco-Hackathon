# %%
import json
import csv
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from datetime import datetime
import re

# %%
pd.options.display.max_colwidth =160

# %%
test = pd.read_csv('test.csv')

# %%
df_1 = pd.read_csv(r"C:\Users\risha\Desktop\convolve-epoch1\BGL.log\xbv.txt", sep = '\s\s+', engine = 'python', header  = None)

# %%
df_1
# Out:
#                                                                                                                                                                      0
# 0      - 1135095509 2005.12.20 R40-M0-N8-I:J18-U01 2005-12-20-08.18.29.693645 R40-M0-N8-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24...
# 1      - 1135095509 2005.12.20 R42-M0-N0-I:J18-U11 2005-12-20-08.18.29.825590 R42-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24...
# 2      - 1135095509 2005.12.20 R42-M0-N0-I:J18-U01 2005-12-20-08.18.29.973194 R42-M0-N0-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24...
# 3      - 1135095510 2005.12.20 R40-M0-N0-I:J18-U11 2005-12-20-08.18.30.113884 R40-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24...
# ...

# %%
# In the first column of the log, "-" indicates non-alert messages while others are alert messages.
# def count_anomaly():
total_size = 0
normal_size = 0
i = 0
with open(r"C:\Users\risha\Desktop\convolve-epoch1\BGL.log\xbv.txt", encoding="utf8") as f:
    for line in f:
        total_size += 1
        if line.split(' ',1)[0] == '-':
            normal_size += 1
            df_1['Class'] = 'normal'
        else: 
            df_1['Class'] = 'anomaly'
print("total size {}, abnormal size {}".format(total_size, total_size - normal_size))
# Out:
# total size 47963, abnormal size 3495

# %%
df_1.columns = ['Log', 'Class']

# %%
df_1['Log'] = df_1['Log'].map(lambda x: x.lstrip('-'))

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
for i in range(100000):
    l1.append(df_1.Log[i].split(' ')[1])
    l2.append(df_1.Log[i].split(' ')[2])
    l3.append(df_1.Log[i].split(' ')[3])
    l4.append(df_1.Log[i].split(' ')[4])
    l5.append(df_1.Log[i].split(' ')[5])
    l6.append(df_1.Log[i].split(' ')[6])
    l7.append(df_1.Log[i].split(' ')[7])
    l8.append(df_1.Log[i].split(' ')[8])
    l9.append(' '.join(df_1.Log[i].split(' ')[9:]))
# l10.append(df['count'][i])

# %%
data_1 = pd.DataFrame(list(zip(l1,l2,l3,l4,l5,l6,l7,l8,l9)))

# %%
data_1[9] = df_1['Class']

# %%
le = list(data_1[3])

# %%
converted_date_and_time = []
for b in le:
        a = datetime.strptime(b, '%Y-%m-%d-%H.%M.%S.%f')
        converted_date_and_time.append(a)

# %%
data_1[3] = converted_date_and_time

# %%
test
# Out:
#             ID  \
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 595295  595295
# 595296  595296
# 595297  595297
# 595298  595298
# 595299  595299
#
#                                                                                                                                                           Log
# 0         1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.363779 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# 1         1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.527847 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# 2         1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.675872 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# ...

# %%
test.drop(['ID'], axis = 1, inplace = True)

# %%
test['Log'] = test['Log'].map(lambda x: x.rstrip('\n'))

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
for i in range(len(test)):
    l1.append(test.Log[i].split(' ')[1])
    l2.append(test.Log[i].split(' ')[2])
    l3.append(test.Log[i].split(' ')[3])
    l4.append(test.Log[i].split(' ')[4])
    l5.append(test.Log[i].split(' ')[5])
    l6.append(test.Log[i].split(' ')[6])
    l7.append(test.Log[i].split(' ')[7])
    l8.append(test.Log[i].split(' ')[8])
    l9.append(' '.join(test.Log[i].split(' ')[9:]))

# %%
test_1 = pd.DataFrame(list(zip(l1,l2,l3,l4,l5,l6,l7,l8,l9)))

# %%
le = list(test_1[3])

# %%
converted_date_and_time = []
for b in le:
        a = datetime.strptime(b, '%Y-%m-%d-%H.%M.%S.%f')
        converted_date_and_time.append(a)

# %%
del a,b

# %%
test_1[3] = converted_date_and_time

# %%
df_1
# Out:
#                                                                                                                                                                        0
# 0                    - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.363779 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# 1                    - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.527847 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# 2                    - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.675872 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# 3                    - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.823719 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# ...

# %%
# hmm = pd.merge(df_1, test, on ='Log', how='inner')

# %% [markdown]
# # yaha se change according to needs

# %%
# change file here
df_1 = pd.read_csv(r"C:\Users\risha\Desktop\convolve-epoch1\BGL.log\xbv.txt", sep = '\s\s+', engine = 'python', header  = None)

# %%
df_1[0] = df_1[0].str.strip()
# test['Log'] = test['Log'].str.strip()

# %%
# change file here
# In the first column of the log, "-" indicates non-alert messages while others are alert messages.
# def count_anomaly():
total_size = 0
normal_size = 0
with open(r"C:\Users\risha\Desktop\convolve-epoch1\BGL.log\xbv.txt", encoding="utf8") as f:
    for line in f:
        total_size += 1
        if line.split(' ',1)[0] == '-':
            normal_size += 1
            df_1['Class'] = 'normal'
        else: 
            df_1['Class'] = 'anomaly'
print("total size {}, abnormal size {}".format(total_size, total_size - normal_size))
# Out:
# total size 47963, abnormal size 3495

# %%
df_1.columns = ['Log', 'Class']

# %%
df_1['Log'] = df_1['Log'].map(lambda x: x.lstrip('-'))

# %%
# change num here
data_4=df_1

# %%
df_1.loc[0,:]
# Out:
# 0    - 1135095509 2005.12.20 R40-M0-N8-I:J18-U01 2005-12-20-08.18.29.693645 R40-M0-N8-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24...
# Name: 0, dtype: object

# %%
data_4[data_4['Class'] == 'anomaly']
# Out:
#                                                                                                                                                                    Log  \
# 0       1135095509 2005.12.20 R40-M0-N8-I:J18-U01 2005-12-20-08.18.29.693645 R40-M0-N8-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 1       1135095509 2005.12.20 R42-M0-N0-I:J18-U11 2005-12-20-08.18.29.825590 R42-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 2       1135095509 2005.12.20 R42-M0-N0-I:J18-U01 2005-12-20-08.18.29.973194 R42-M0-N0-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 3       1135095510 2005.12.20 R40-M0-N0-I:J18-U11 2005-12-20-08.18.30.113884 R40-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# ...

# %%
# l1=[]
# l2=[]
# l3=[]
# l4=[]
# l5=[]
# l6=[]
# l7=[]
# l8=[]
# l9=[]
# l10=[]
# for i in range(100000):
#     l1.append(df_1.Log[i].split(' ')[1])
#     l2.append(df_1.Log[i].split(' ')[2])
#     l3.append(df_1.Log[i].split(' ')[3])
#     l4.append(df_1.Log[i].split(' ')[4])
#     l5.append(df_1.Log[i].split(' ')[5])
#     l6.append(df_1.Log[i].split(' ')[6])
#     l7.append(df_1.Log[i].split(' ')[7])
#     l8.append(df_1.Log[i].split(' ')[8])
#     l9.append(' '.join(df_1.Log[i].split(' ')[9:]))

# %%
# change num here
# data_1 = pd.DataFrame(list(zip(l1,l2,l3,l4,l5,l6,l7,l8,l9)))

# %%
# change num here
data_1[9] = df_1['Class']

# %%
# change num here
le = list(data_1[3])

# %%
converted_date_and_time = []
for b in le:
        a = datetime.strptime(b, '%Y-%m-%d-%H.%M.%S.%f')
        converted_date_and_time.append(a)

# %%
del a,b

# %%
# change num here
data_3[3] = converted_date_and_time

# %%
data_3
# Out:
#                 0           1                    2                          3  \
# 0      1118292402  2005.06.08  R20-M1-NF-C:J16-U01 2005-06-08 21:46:42.818121
# 1      1118292402  2005.06.08  R20-M1-NF-C:J10-U01 2005-06-08 21:46:42.837589
# 2      1118292402  2005.06.08  R20-M1-NF-C:J12-U01 2005-06-08 21:46:42.865021
# 3      1118292402  2005.06.08  R20-M1-NF-C:J12-U01 2005-06-08 21:46:42.876375
# 4      1118292402  2005.06.08  R20-M1-NF-C:J08-U01 2005-06-08 21:46:42.895281
# ...           ...         ...                  ...                        ...
# 99995  1118547003  2005.06.11  R30-M0-N9-C:J16-U01 2005-06-11 20:30:03.739959
# 99996  1118547003  2005.06.11  R30-M0-N9-C:J16-U01 2005-06-11 20:30:03.837634
# 99997  1118547004  2005.06.11  R30-M0-N9-C:J16-U01 2005-06-11 20:30:04.112979
# 99998  1118547004  2005.06.11  R30-M0-N9-C:J16-U01 2005-06-11 20:30:04.231448
# 99999  1118547004  2005.06.11  R30-M0-N9-C:J16-U01 2005-06-11 20:30:04.339707
#
# ...

# %%
test_1[7].value_counts()
# Out:
# FATAL      361999
# INFO       233148
# WARNING        56
# SEVERE         34
# ERROR          34
# FAILURE        29
# Name: 7, dtype: int64

# %%
test_time = list(test_1[3])
data_time = list(data_1[3])

# %%
test_1[7].value_counts()
# Out:
# FATAL      361999
# INFO       233148
# WARNING        56
# SEVERE         34
# ERROR          34
# FAILURE        29
# Name: 7, dtype: int64

# %%
Class = []
for row in test_1[7]:
    if row == 'INFO' : Class.append('normal')
    elif row == 'WARNING' : Class.append('normal')
    elif row == 'SEVERE' : Class.append('normal')
    elif row == 'ERROR' : Class.append('normal')
    elif row == 'FAILURE' : Class.append('normal')
    else: Class.append('anomaly')

# %%
# test_1.loc[0:10,:]

# %%
test
# Out:
#             ID  \
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 595295  595295
# 595296  595296
# 595297  595297
# 595298  595298
# 595299  595299
#
#                                                                                                                                                                     Log
# 0                   1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.363779 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# 1                   1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.527847 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# 2                   1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.675872 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected\n
# ...

# %%
hmm = pd.merge(test, data_1 on ='Log', how='left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [666], in <cell line: 1>()
# ----> 1 hmm = pd.merge(test, data_1, data_2, on ='Log', how='left')
#
# TypeError: merge() got multiple values for argument 'how'

# %%
hmm['Class'].value_counts()
# Out:
# normal    100000
# Name: Class, dtype: int64

# %%
hmm
# Out:
#             ID  \
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 595295  595295
# 595296  595296
# 595297  595297
# 595298  595298
# 595299  595299
#
#                                                                                                                                                                     Log  \
# 0                     1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.363779 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# 1                     1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.527847 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# 2                     1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.675872 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# ...

# %%
data_3
# Out:
#                                                                                                                                                Log  \
# 0                    1118292402 2005.06.08 R20-M1-NF-C:J16-U01 2005-06-08-21.46.42.818121 R20-M1-NF-C:J16-U01 RAS KERNEL INFO generating core.4096
# 1                     1118292402 2005.06.08 R20-M1-NF-C:J10-U01 2005-06-08-21.46.42.837589 R20-M1-NF-C:J10-U01 RAS KERNEL INFO generating core.129
# 2                       1118292402 2005.06.08 R20-M1-NF-C:J12-U01 2005-06-08-21.46.42.865021 R20-M1-NF-C:J12-U01 RAS KERNEL INFO generating core.1
# 3                    1118292402 2005.06.08 R20-M1-NF-C:J12-U01 2005-06-08-21.46.42.876375 R20-M1-NF-C:J12-U01 RAS KERNEL INFO generating core.4097
# 4                       1118292402 2005.06.08 R20-M1-NF-C:J08-U01 2005-06-08-21.46.42.895281 R20-M1-NF-C:J08-U01 RAS KERNEL INFO generating core.2
# ...

# %%
data_3.to_csv('data_3.csv')

# %%
data_48
# Out:
#                                                                                                                                                                    Log  \
# 0       1135095509 2005.12.20 R40-M0-N8-I:J18-U01 2005-12-20-08.18.29.693645 R40-M0-N8-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 1       1135095509 2005.12.20 R42-M0-N0-I:J18-U11 2005-12-20-08.18.29.825590 R42-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 2       1135095509 2005.12.20 R42-M0-N0-I:J18-U01 2005-12-20-08.18.29.973194 R42-M0-N0-I:J18-U01 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# 3       1135095510 2005.12.20 R40-M0-N0-I:J18-U11 2005-12-20-08.18.30.113884 R40-M0-N0-I:J18-U11 RAS KERNEL INFO ciod: generated 128 core files for program /g/g24/...
# ...
